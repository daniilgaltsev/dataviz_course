# %% [markdown]
# # Creating Visualization Prototypes
#
# > Creating the visualization prototypes for our observations

# %%
import altair as alt
import pandas as pd
import numpy as np

from dataviz_course.explore_data import prepare_dataset

# %%
data = prepare_dataset()
data.head()
# Out:
#   Work Year          Experience Level                   Job Title  \
# 0      2020  Mid-level / Intermediate              Data Scientist
# 1      2020     Senior-level / Expert  Machine Learning Scientist
# 2      2020     Senior-level / Expert           Big Data Engineer
# 3      2020  Mid-level / Intermediate        Product Data Analyst
# 4      2020     Senior-level / Expert   Machine Learning Engineer
#
#    Salary (usd) Employee Residence Company Location On-site/Remote  \
# 0         79833                 DE               DE        On-site
# 1        260000                 JP               JP        On-site
# 2        109024                 GB               GB         Hybrid
# 3         20000                 HN               HN        On-site
# 4        150000                 US               US         Hybrid
#
#   Number of Employees  Working for a Foreign Company
# 0                >250                           True
# 1                 <50                           True
# 2              50-250                           True
# 3                 <50                           True
# 4                >250                           True
